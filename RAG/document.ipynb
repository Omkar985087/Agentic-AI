# %% [markdown]
# Data Ingestion

# %%
#document structure
from langchain_core.documents import Document

# %%
from importlib.metadata import metadata
doc=Document(
    page_content="this is the main text content i am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Omkar",
        "data_created":"2025-06-08"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Omkar', 'data_created': '2025-06-08'}, page_content='this is the main text content i am using to create RAG')
